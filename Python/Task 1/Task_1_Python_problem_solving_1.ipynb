# %% [markdown]
# ### Problem 1 username and password validation

# %%
uname="admin"
pwd="1234"
#getting username and pwd from user
username=input("Emter Username:")
password=input("Enter the Password:")

# condition to match uname and pwd
if username==uname and password==pwd:
    print("Login Successful..")
else:
    print("Invalid Credentials.")
# Out:
# Login Successful..

# %% [markdown]
# ## Probelm 2
# ### marks and total count of pass and fail students

# %%
marks=[45,78,90,33,60]
pass_count=0
fail_count=0

for mark in marks:
    if mark >=50:
        pass_count+=1
    else:
        fail_count+=1
print("Marks of students are:",marks)  
print("Total Students:",len(marks))
print("Total Passed Students:",pass_count)
print("Total Failed Students:",fail_count)
# Out:
# Marks of students are: [45, 78, 90, 33, 60]
# Total Students: 5
# Total Passed Students: 3
# Total Failed Students: 2

# %% [markdown]
# ## Problem 3
# ### names are given to clear the cleaned data

# %%
names=["Alice ","Bob","CHARLIE"]

cleaned_names=[]

for name in names:
    cleaned_name=name.strip().lower()
    # used strip for removed white space, and lower for chage to lowercase
    cleaned_names.append(cleaned_name)

print("Cleaned Names are:",cleaned_names)
# Out:
# Cleaned Names are: ['alice', 'bob', 'charlie']

# %% [markdown]
# ## Problem 4
# ### message given from it find length of message

# %%
messages=["Hi","Welcome to the platform","OK"]
for message in messages:
    length=len(message)
    print(f"Message: '{message}' | Length: {length}")
# used len function for find length
    if length>10:
        print("Long Message Detected...")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# Long Message Detected...
# Message: 'OK' | Length: 2

# %% [markdown]
# ## Problem 5
# ### logs are given count the error log from logs..

# %%
logs=["INFO","ERROR","WARNING","ERROR"]
# used count function to count the tota ERROR words in list
error_count=logs.count("ERROR")
print("Total 'ERROR' entries are: ",error_count)
index_of_ERROR=logs.index('ERROR')
print("The index of 'ERROR' is:",index_of_ERROR)
# Out:
# Total 'ERROR' entries are:  2
# The index of 'ERROR' is: 1
