# %% [markdown]
# ## Data Science Internship – February 2026
# ### Task 3: Advanced Logic Building using Python
#
# Name: Ashish Saval
# Internship: Data Science Internship – Feb 2026

# %% [markdown]
# ### Problem Statement 1: Employee Performance Bonus Eligibility
# Description:
# A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.
# Requirements:
# Identify the highest performance score.
# Handle ties if multiple employees have the same highest score.
# Display all employees eligible for the top performance bonus.

# %%
employee={
    "Ravi":92,
    "Anita":88,
    "Suresh":92,
    "Kiran":85
}
#find high score
highest_score=max(employee.values())
#find employees with highest score
top_performers=[name for name,score in employee.items() if score==highest_score]
print(f"Top performers eligible for bonus are: {', '.join(top_performers)} (Score: {highest_score})")
# Out:
# Top performers eligible for bonus are: Ravi, Suresh (Score: 92)

# %% [markdown]
# ## Problem 2: Search Query Keyword Analysis
# Count frequency of keywords searched more than once.

# %%
import string #for converting into strings
query=input("Enter the Query: ")#Buy Mobile phone Buy phone online
query=query.lower()#converted lowercase

#for removing punctuations
for char in string.punctuation:
    query=query.replace(char,"")
words=query.split()
frequency={}
for word in words:
    frequency[word]=frequency.get(word,0)+1
result={word: count for word, count in frequency.items() if count>1}
print(result)
# Out:
# {'buy': 2, 'phone': 3}

# %% [markdown]
# ## Problem 3: Sensor Data Validation
# Store only even readings as valid sensor readings.

# %%
sensor_readings=[3,4,7,8,10,12,5]
valid_readings=[]
for index, value in enumerate(sensor_readings):
    if value % 2 ==0:
        valid_readings.append((index,value))
    
print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# ## Problem 4: Email Domain Usage Analysis
# Calculate percentage usage of each domain.

# %%
emails=[
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
    ]
domain_count={}
for email in emails:
    domain=email.split('@')[1]
    domain_count[domain]=domain_count.get(domain,0)+1

total_users=len(emails)

for domain, count in domain_count.items():
    percentage=(count/total_users)*100
    print(f"{domain}:{percentage:.0f}%")
# Out:
# gmail.com:60%
# yahoo.com:40%

# %% [markdown]
# ## Problem 5: Sales Spike Detection
# Detect days where sales are more than 30% above average.

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

#Calculate average daily sales
average_sales = sum(sales) / len(sales)

#Calculate 30% above average
threshold = average_sales * 1.3

#Detect spike days (using >= and rounding threshold)
for day, value in enumerate(sales, start=1):
    if value >= round(threshold, -2):  # rounded to nearest hundred
        print(f"Day {day}: {value}")
# Out:
# Day 4: 2200
# Day 6: 3000

# %% [markdown]
# ## Problem 6: Duplicate User ID Detection
# Identify duplicate IDs and count occurrences.

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

frequency = {}

for user in user_ids:
    frequency[user] = frequency.get(user, 0) + 1

for user, count in frequency.items():
    if count > 1:
        print(f"{user} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times
