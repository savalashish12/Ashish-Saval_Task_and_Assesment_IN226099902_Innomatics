# %% [markdown]
# ## Name: Ashish Saval
# ### Id: IN226099902
# #### Internship tasks are for the NLP Tasks preprocessing.

# %% [markdown]
# ## Task 1: Conceptual Understanding (Mandatory – Written)
# ### Answer the following questions in your own words:
# ### What is the difference between "Love" and "love" in NLP?
# ### What happens if stopwords are not removed?
# ### Provide two real-world scenarios where removing stopwords can be harmful.
# ### Explain the difference between stemming and lemmatization.

# %% [markdown]
# ### Question 1- What is the difference between "Love" and "love" in NLP?
# ### Answer- "Love" and "love" in nlp are treated as two different tokens beacasue their unicode, their ASCII Values 0|1 values are different. Converting everything to lowercase helps model realize they represnting the same concept.

# %% [markdown]
# ### Question2- What happens if stopwords are not removed?
# ### Answer- Stopwords are the small words whose not any meaning to understand and analyze based on those words, this are words like "the","as","is","at","those" this are different tokens values. If not removed they make noise like there no use and they feel only memory so remove them is good option, so model can focus on meaningful keywords and analyze the perfect output.

# %% [markdown]
# ### Question 3- Provide two real-world scenarios where removing stopwords can be harmful.
# ### Answer- In Sentiment Analysis: Words like "not" or "no" are often in stopwords lists, If you remove them, "I am not Happy" becomes "I Happy", completely chages the sentiment of feeling.
# ### Author Identification: The way an author uses commmon words likeprepositions and articles is oftena unique "fingerprint" of their writing style. Remvoing them destroying their pattern so we can't recognize identify the author although author is same

# %% [markdown]
# ### Explain the difference between stemming and lemmatization.
# ### Answer- Stemming: A process that chops odd the ends of words like in sentence the more longer words are there using class of words like "running" can be converted into "run" by appling the stemming process although its optional.
# ### Lemmatization: Uses a voabulary and analysis to return the base or dictionary form of word , known as lemma(eg. "better"--> "good"). it's more accurate but computatnioally slower.
